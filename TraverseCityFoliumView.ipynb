# %%
# %%capture
# !pip install folium
# !pip install python-dotenv
# !pip install bs4

# %%
import numpy as np
import pandas as pd 
import random 
from itertools import permutations
import folium
import os 
from dotenv import load_dotenv
import requests
from bs4 import BeautifulSoup as bs

# %%
load_dotenv('.env')
# Out:
# True

# %% [markdown]
# ## Code for if you want to use Google Maps API
# * I chose not to in order to avoid account charges

# %%
# api_key = os.environ.get("API_KEY")
# secret = os.environ.get("SECRET")

# def get_street_view_iframe(api_key, lat, lng):
#     # construct the URL
#     url = f"https://maps.googleapis.com/maps/api/streetview?size=400x400&location={lat},{lng}&fov=80&heading=70&pitch=0&key={api_key}"
#     # make the GET request
#     response = requests.get(url)
#     # check for a successful request
#     if response.ok:
#         soup = bs(response.text, 'html.parser')
#         iframe_code = soup.find("iframe")
#         if iframe_code:
#             iframe_code = iframe_code["src"]
#             return iframe_code
#         else:
#             print(f'Error: {response.status_code}')

# # Use the function 
# coordinates = [[44.75963839118154, -85.62227002634658],
#                [44.763348944275855, -85.61732573015192],
#                [44.764057282096225, -85.60921267956574],
#                [44.76377210772948, -85.61560278178136],
#                [44.76273377253821, -85.6178456675372],
#                [44.7645293793255, -85.62416399559677],
#                [44.763094220537106, -85.62583613456133],
#                [44.76319585288766, -85.62349143759874],
#                [44.76279716748365, -85.62129443362772],
#                [44.7610275080454, -85.62146561347643],
#                [44.76065472111241, -85.62179328007855],
#                [44.759274053696, -85.62117545422579],
#                [44.75925369944749, -85.62265385596211],
#                [44.76587156608438, -85.62659115367947],
#                [44.764400857422466, -85.628613901701], # NorthPeak
#                 [44.76426512771712, -85.6292543081359], # Folgarelli's
#                 [44.76377649813742, -85.63145271828563], # Burrit's
#                 [44.763952948185654, -85.63192107535336], # Grand Traverse Pie Company
#                 [44.76429906017438, -85.63260927331326], # Cheese Lady
#                 [44.76429312855028, -85.63263329296178], # Lil' Bo
#                 [44.75641651539438, -85.64331284491067], # Village of Grand Traverse
#                 [44.75519761187204, -85.64267351000152], # Stellas
#                [44.7562585034253, -85.64360787280982],
#                [44.756475634178756, -85.64506163007684],
#                [44.75602672474162, -85.64541579717158],
#                [44.992506674419786, -85.4793547759827],
#                [44.96177939608813, -85.48530926136317],
#                [44.954605874626296, -85.48998584807917],
#                [44.94378795225628, -85.50502261193782],
#                [44.93701111193567, -85.5056234940245],
#                [44.93471884774591, -85.49602881534076],
#                [44.9199551582983, -85.5020659846592]]


# for coord in coordinates:
#     lat, lng = coord
#     iframe = get_street_view_iframe(api_key, lat, lng)
#     print(iframe)

# %%
coordinates = [[44.75963839118154, -85.62227002634658],
               [44.763348944275855, -85.61732573015192],
               [44.764057282096225, -85.60921267956574],
               [44.76377210772948, -85.61560278178136],
               [44.76273377253821, -85.6178456675372],
               [44.7645293793255, -85.62416399559677],
               [44.763094220537106, -85.62583613456133],
               [44.76319585288766, -85.62349143759874],
               [44.76279716748365, -85.62129443362772],
5f0.7820865974627469" width="600" height="450" style="border:0;" allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade"></iframe>""",
              """<iframe src="https://www.google.com/maps/embed?pb=!4v1674348288920!6m8!1m7!1sCr5BO3r2BD59HaI-G_dPGA!2m2!1d44.99027431416125!2d-85.47967294847594!3f1.3330923708501814!4f-14.392244480638013!5f0.7820865974627469" width="600" height="450" style="border:0;" allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade"></iframe>""",
              """<iframe src="https://www.google.com/maps/embed?pb=!4v1674348526622!6m8!1m7!1sCAoSLEFGMVFpcE1tcVVOYnl6ZldqZjdERXVtay12RVJ3Q0duQTNJOTlERXlLdXA1!2m2!1d44.9615972!2d-85.4851376!3f154.95224029998028!4f-2.0816919932977527!5f0.7820865974627469" width="600" height="450" style="border:0;" allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade"></iframe>""",
              """<iframe src="https://www.google.com/maps/embed?pb=!4v1674348601298!6m8!1m7!1szAtCECbyicBmx5Cz3yHfhA!2m2!1d44.95402885902219!2d-85.49013229226472!3f40.34448632605089!4f1.9625070033655163!5f0.7820865974627469" width="600" height="450" style="border:0;" allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade"></iframe>""",
              """<iframe src="https://www.google.com/maps/embed?pb=!4v1674348812893!6m8!1m7!1sy_Yf3BLzkn6ZIF9HGhc2Xw!2m2!1d44.94379294526453!2d-85.50509442010488!3f104.85805927594265!4f-11.827385734688761!5f0.7820865974627469" width="600" height="450" style="border:0;" allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade"></iframe>""",
              """<iframe src="https://www.google.com/maps/embed?pb=!4v1674348909695!6m8!1m7!1svGgX32a5y5D6NLV9k8XWcw!2m2!1d44.93635201119594!2d-85.50516360841587!3f245.29208106429883!4f-6.799568435136592!5f0.7820865974627469" width="600" height="450" style="border:0;" allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade"></iframe>""",
              """<iframe src="https://www.google.com/maps/embed?pb=!4v1674348946573!6m8!1m7!1sCAoSLEFGMVFpcE5Fc3l3eEJLX0cyMzJtU1NocHlGd0o1b25sTWJpNDM0dktXeHpp!2m2!1d44.934172!2d-85.4959859!3f343.35664519116693!4f-5.906085552666781!5f0.7820865974627469" width="600" height="450" style="border:0;" allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade"></iframe>""",
              """<iframe src="https://www.google.com/maps/embed?pb=!4v1674349030147!6m8!1m7!1sCAoSLEFGMVFpcFBReGR5bEdEc0xpOG1JQmJOSy1Fd0FxcHVSU2hxT1hFZWp6Z0lo!2m2!1d44.9195905!2d-85.5021089!3f104.73862830854517!4f-8.844997255566568!5f0.7820865974627469" width="600" height="450" style="border:0;" allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade"></iframe>""",

              ]



stairwells = pd.DataFrame(coordinates, columns=['Latitude','Longitude'])
stairwells['Location'] = location
stairwells['streetview'] = streetview
stairwells
# Out:
#      Latitude  Longitude                               Location  \
# 0   44.759638 -85.622270                   oldTownParkingGarage
# 1   44.763349 -85.617326                     HardyParkingGarage
# 2   44.764057 -85.609213                            PlanteMoran
# 3   44.763772 -85.615603                         behindCoinSlot
# 4   44.762734 -85.617846                         ParkPlaceHotel
# 5   44.764529 -85.624164                         FifthThirdBank
# 6   44.763094 -85.625836                        StonePathOnPine
# 7   44.763196 -85.623491                         WilsonAntiques
# 8   44.762797 -85.621294                         GreenLeafTrust
# 9   44.761028 -85.621466                     OutdoorFireflyBack
# 10  44.760655 -85.621793                       HagertyInsurance
# 11  44.759274 -85.621175                      OldTownePlayHouse
# 12  44.759254 -85.622654                          IvyApartments
# 13  44.765872 -85.626591                           Hotel Indigo
# ...

# %%
map = folium.Map(location=[44.75963839118154, -85.62227002634658], zoom_start=13)
feature_group = folium.FeatureGroup(name="Street View")

for coord, name, sv in zip(coordinates, location, streetview):
    lat, lng = coord
    iframe = folium.IFrame(html=sv, width=600, height=450)
    feature_group.add_child(folium.Marker(location=[lat, lng],
                                          popup=folium.Popup(iframe),
                                          icon=folium.Icon(color="blue"),
                                          tooltip=name))

map.add_child(feature_group)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map.save('TC360.html')

# %%
map.save('tc360.jpg')
